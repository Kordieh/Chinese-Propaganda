# %%
import pandas as pd
ruta_archivo = 'comercio_cultural_limpia.csv'
df = pd.read_csv('comercio_cultural_limpia.csv')
df.head(55)
# Out:
#                   País                                Producto        Flujo  \
# 0                China  Software, videojuegos y recorded media  Exportación
# 1                China  Software, videojuegos y recorded media  Importación
# 2                China  Software, videojuegos y recorded media  Exportación
# 3                China  Software, videojuegos y recorded media  Exportación
# 4                China  Software, videojuegos y recorded media  Exportación
# 5                China  Software, videojuegos y recorded media  Exportación
# 6                China  Software, videojuegos y recorded media  Exportación
# 7                China  Música, artes performativas y visuales  Exportación
# 8                China  Música, artes performativas y visuales  Importación
# 9                China                  Libros y publicaciones  Exportación
# 10               China                  Libros y publicaciones  Importación
# ...
